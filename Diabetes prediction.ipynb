# %%
# step 01: import library
import pandas as pd

# %%
# step 02: import data
diabetes = pd.read_csv('https://github.com/YBIFoundation/Dataset/raw/main/Diabetes.csv')

# %%
diabetes.head()
# Out:
#    pregnancies  glucose  diastolic  triceps  insulin   bmi    dpf  age  \
# 0            6      148         72       35        0  33.6  0.627   50
# 1            1       85         66       29        0  26.6  0.351   31
# 2            8      183         64        0        0  23.3  0.672   32
# 3            1       89         66       23       94  28.1  0.167   21
# 4            0      137         40       35      168  43.1  2.288   33
#
#    diabetes
# 0         1
# 1         0
# 2         1
# 3         0
# 4         1

# %%
diabetes.shape
# Out:
# (768, 9)

# %%
diabetes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   pregnancies  768 non-null    int64
#  1   glucose      768 non-null    int64
#  2   diastolic    768 non-null    int64
#  3   triceps      768 non-null    int64
#  4   insulin      768 non-null    int64
#  5   bmi          768 non-null    float64
#  6   dpf          768 non-null    float64
#  7   age          768 non-null    int64
#  8   diabetes     768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
diabetes.describe()
# Out:
#        pregnancies     glucose   diastolic     triceps     insulin  \
# count   768.000000  768.000000  768.000000  768.000000  768.000000
# mean      3.845052  120.894531   69.105469   20.536458   79.799479
# std       3.369578   31.972618   19.355807   15.952218  115.244002
# min       0.000000    0.000000    0.000000    0.000000    0.000000
# 25%       1.000000   99.000000   62.000000    0.000000    0.000000
# 50%       3.000000  117.000000   72.000000   23.000000   30.500000
# 75%       6.000000  140.250000   80.000000   32.000000  127.250000
# max      17.000000  199.000000  122.000000   99.000000  846.000000
#
#               bmi         dpf         age    diabetes
# count  768.000000  768.000000  768.000000  768.000000
# mean    31.992578    0.471876   33.240885    0.348958
# std      7.884160    0.331329   11.760232    0.476951
# min      0.000000    0.078000   21.000000    0.000000
# 25%     27.300000    0.243750   24.000000    0.000000
# 50%     32.000000    0.372500   29.000000    0.000000
# 75%     36.600000    0.626250   41.000000    1.000000
# max     67.100000    2.420000   81.000000    1.000000

# %%
diabetes.columns
# Out:
# Index(['pregnancies', 'glucose', 'diastolic', 'triceps', 'insulin', 'bmi',
#        'dpf', 'age', 'diabetes'],
#       dtype='object')

# %%
#step 03: Define(x) and target(y)
y = diabetes['diabetes']
X = diabetes[['pregnancies']]

# %%
y.shape
# Out:
# (768,)

# %%
X.shape
# Out:
# (768, 1)

# %%
#step 04: train_test_split
from sklearn.model_selection import train_test_split
X_train, X_test,y_train, y_test =train_test_split(X,y, train_size=0.7, random_state = 2529)

# %%
X_train.shape,X_test.shape,y_train.shape,y_test.shape
# Out:
# ((537, 1), (231, 1), (537,), (231,))

# %%
#step 05: Select model (best fit)
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
#step 06: train and fit model
model.fit(X,y)
# Out:
# LinearRegression()

# %%
model.intercept_
# Out:
# 0.22818960329237795

# %%
model.coef_
# Out:
# array([0.03140887])

# %%
# step 07 : Model predict
y_pred = model.predict(X_test)

# %%
y_pred
# Out:
# array([0.29100734, 0.3224162 , 0.47946054, 0.29100734, 0.38523394,
#        0.69932261, 0.2281896 , 0.25959847, 0.41664281, 0.29100734,
#        0.3224162 , 0.35382507, 0.38523394, 0.29100734, 0.2281896 ,
#        0.3224162 , 0.51086941, 0.35382507, 0.35382507, 0.2281896 ,
#        0.25959847, 0.51086941, 0.41664281, 0.29100734, 0.29100734,
#        0.3224162 , 0.25959847, 0.3224162 , 0.29100734, 0.47946054,
#        0.47946054, 0.44805167, 0.38523394, 0.47946054, 0.2281896 ,
#        0.25959847, 0.3224162 , 0.25959847, 0.38523394, 0.2281896 ,
#        0.29100734, 0.2281896 , 0.25959847, 0.35382507, 0.25959847,
#        0.44805167, 0.47946054, 0.2281896 , 0.41664281, 0.35382507,
#        0.25959847, 0.44805167, 0.25959847, 0.3224162 , 0.25959847,
#        0.47946054, 0.47946054, 0.25959847, 0.51086941, 0.35382507,
#        0.38523394, 0.25959847, 0.51086941, 0.41664281, 0.35382507,
#        0.35382507, 0.25959847, 0.25959847, 0.29100734, 0.47946054,
#        0.44805167, 0.2281896 , 0.2281896 , 0.25959847, 0.25959847,
#        0.2281896 , 0.25959847, 0.2281896 , 0.2281896 , 0.38523394,
#        0.2281896 , 0.2281896 , 0.29100734, 0.35382507, 0.29100734,
#        0.2281896 , 0.2281896 , 0.25959847, 0.35382507, 0.25959847,
#        0.41664281, 0.29100734, 0.25959847, 0.25959847, 0.29100734,
#        0.38523394, 0.51086941, 0.2281896 , 0.38523394, 0.38523394,
#        0.2281896 , 0.3224162 , 0.44805167, 0.44805167, 0.3224162 ,
#        0.3224162 , 0.3224162 , 0.38523394, 0.2281896 , 0.44805167,
#        0.51086941, 0.47946054, 0.25959847, 0.51086941, 0.54227827,
#        0.41664281, 0.41664281, 0.3224162 , 0.35382507, 0.29100734,
#        0.38523394, 0.2281896 , 0.2281896 , 0.35382507, 0.2281896 ,
#        0.41664281, 0.41664281, 0.2281896 , 0.35382507, 0.38523394,
#        0.3224162 , 0.41664281, 0.29100734, 0.29100734, 0.29100734,
#        0.47946054, 0.29100734, 0.25959847, 0.29100734, 0.51086941,
#        0.25959847, 0.2281896 , 0.25959847, 0.47946054, 0.3224162 ,
#        0.47946054, 0.25959847, 0.2281896 , 0.41664281, 0.25959847,
#        0.3224162 , 0.35382507, 0.25959847, 0.35382507, 0.44805167,
#        0.38523394, 0.57368714, 0.3224162 , 0.3224162 , 0.25959847,
#        0.29100734, 0.2281896 , 0.25959847, 0.25959847, 0.3224162 ,
#        0.25959847, 0.25959847, 0.35382507, 0.51086941, 0.25959847,
#        0.2281896 , 0.35382507, 0.2281896 , 0.51086941, 0.25959847,
#        0.25959847, 0.35382507, 0.2281896 , 0.29100734, 0.41664281,
#        0.25959847, 0.25959847, 0.38523394, 0.47946054, 0.25959847,
#        0.3224162 , 0.29100734, 0.29100734, 0.51086941, 0.25959847,
#        0.2281896 , 0.29100734, 0.25959847, 0.54227827, 0.44805167,
#        0.29100734, 0.25959847, 0.41664281, 0.35382507, 0.60509601,
#        0.35382507, 0.25959847, 0.54227827, 0.25959847, 0.3224162 ,
#        0.51086941, 0.25959847, 0.3224162 , 0.47946054, 0.63650488,
#        0.38523394, 0.35382507, 0.44805167, 0.66791374, 0.51086941,
#        0.2281896 , 0.41664281, 0.29100734, 0.51086941, 0.2281896 ,
#        0.44805167, 0.29100734, 0.44805167, 0.44805167, 0.3224162 ,
#        0.29100734, 0.25959847, 0.25959847, 0.25959847, 0.41664281,
#        0.63650488])

# %%
#step 08 : Accurecy
from sklearn.metrics import mean_absolute_error,mean_absolute_percentage_error,mean_squared_error

# %%
mean_squared_error(y_pred, y_test)
# Out:
# 0.21999611809547664

# %%
mean_absolute_error(y_pred, y_test)
# Out:
# 0.4354714537289006

# %%
mean_absolute_percentage_error(y_pred, y_test)
# Out:
# 1.3319999664780122
